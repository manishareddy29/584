# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/refs/heads/main/youtubesample.csv ")
df
# Out:
#          video_id trending_date  \
# 0     m8Dqg8iz5Fo      18.09.05
# 1     2yCp-Dj5-7c      17.16.12
# 2     H00djJq68VE      17.27.12
# 3     oTObwUiXdYY      17.19.11
# 4     yvicqMrAHvQ      18.05.02
# ...           ...           ...
# 4995  bqFjyo7I8fY      18.01.03
# 4996  K0u_kAWLJOA      18.25.01
# 4997  XGd1dq1BatM      18.19.03
# 4998  vGTTSdrV37U      18.04.04
# 4999  DkeiKbqa02g      18.22.05
#
#                                                   title  \
# 0     MY INSTAGRAM FOLLOWERS PICK MY FULL FACE OF MA...
# 1     Does Tiffany Haddish Think NeNe Leakes Is Funn...
# 2     Panettone (Italian Christmas Bread) - Food Wishes
# 3     7.3 Magnitude Earthquake Along Iraq-Iran Borde...
# 4               Turkish Airlines - 5 Senses with Dr. Oz
# ...                                                 ...
# 4995          Red Velvet 레드벨벳 '봐 (Look)' Dance Practice
# 4996                   God of War – Story Trailer | PS4
# 4997  Halsey - Alone (Audio) ft. Big Sean, Stefflon Don
# ...

# %%
import pandas as pd

# Example: Simple DataFrame with employee data
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "Department": ["HR", "IT", "Finance"]
}
df = pd.DataFrame(data)

# %%
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie'],
#  'Age': [25, 30, 35],
#  'Department': ['HR', 'IT', 'Finance']}

# %%
import numpy as np

# Random dataset with 100 rows and 3 columns
data = pd.DataFrame(
    np.random.rand(100, 3),
    columns=["Feature1", "Feature2", "Feature3"]
)

# %%
data
# Out:
#     Feature1  Feature2  Feature3
# 0   0.558774  0.766636  0.866520
# 1   0.279473  0.353800  0.152200
# 2   0.904284  0.637985  0.345663
# 3   0.338065  0.900802  0.915075
# 4   0.463719  0.569240  0.099424
# ..       ...       ...       ...
# 95  0.725265  0.174670  0.947208
# 96  0.945293  0.551020  0.477247
# 97  0.879110  0.083440  0.596873
# 98  0.548849  0.737081  0.944742
# 99  0.808869  0.640731  0.029723
#
# [100 rows x 3 columns]

# %%
# Time series data: daily sales
dates = pd.date_range(start="2023-01-01", periods=30)
sales = np.random.randint(100, 200, size=len(dates))

time_series_df = pd.DataFrame({"Date": dates, "Sales": sales})
time_series_df.set_index("Date", inplace=True)

# %%
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                '2023-01-29', '2023-01-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
# Dataset with NaN values
data = {
    "Name": ["Alice", "Bob", "Charlie", None],
    "Age": [25, 30, None, 40],
    "Score": [85.0, 90.5, None, 88.0]
}
missing_data_df = pd.DataFrame(data)

# %%
missing_data_df
# Out:
#       Name   Age  Score
# 0    Alice  25.0   85.0
# 1      Bob  30.0   90.5
# 2  Charlie   NaN    NaN
# 3     None  40.0   88.0

# %%
# Sales data by category and month
data = {
    "Month": ["January", "January", "February", "February"],
    "Category": ["Electronics", "Clothing", "Electronics", "Clothing"],
    "Sales": [2000, 1500, 2500, 1700]
}
grouped_df = pd.DataFrame(data)

# %%
grouped_df
# Out:
#       Month     Category  Sales
# 0   January  Electronics   2000
# 1   January     Clothing   1500
# 2  February  Electronics   2500
# 3  February     Clothing   1700
